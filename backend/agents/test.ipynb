# %% [markdown]
# ### RuntimeAI Collector Test

# %%
import sys
import os

# Add backend2 directory to python path so we can import agents
# Assuming the notebook is running from backend/agents/
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))
backend2_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

if backend2_dir not in sys.path:
    sys.path.append(backend2_dir)
if project_root not in sys.path:
    sys.path.append(project_root)

try:
    from agents.collectors.runtime_collector import RuntimeCollector
    print("Successfully imported RuntimeCollector")
except ImportError as e:
    print(f"Import failed: {e}")
    try:
        from backend.agents.collectors.runtime_collector import RuntimeCollector
        print("Successfully imported RuntimeCollector from backend2")
    except ImportError as e2:
        print(f"Import failed again: {e2}")

# Configuration
start_date = "2026-02-01"
end_date = "2026-02-07"

if 'RuntimeCollector' in locals():
    print(f"Running RuntimeCollector from {start_date} to {end_date}...")
    collector = RuntimeCollector(start_date=start_date, end_date=end_date)
    results = collector.run()
    
    print(f"\nCollected {len(results)} articles:")
    for item in results:
        print(f"- [{item.get('date')}] {item.get('raw_title', 'No Title')} ({item.get('source_name', 'Unknown')})")
else:
    print("RuntimeCollector class not available.")

# %% [markdown]
# ### Robot Collector Test

# %%
# Robot Collector Test
import sys
import os

# Add backend2 directory to python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))
backend2_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

if backend2_dir not in sys.path:
    sys.path.append(backend2_dir)
if project_root not in sys.path:
    sys.path.append(project_root)

try:
    from agents.collectors.robot_collector import RobotCollector
    print("Successfully imported RobotCollector")
except ImportError as e:
    print(f"Import failed: {e}")
    try:
        from backend.agents.collectors.robot_collector import RobotCollector
        print("Successfully imported RobotCollector from backend2")
    except ImportError as e2:
        print(f"Import failed again: {e2}")

# Configuration
start_date = "2026-02-05"
end_date = "2026-02-05"

if 'RobotCollector' in locals():
    print(f"Running RobotCollector from {start_date} to {end_date}...")
    robot_collector = RobotCollector(start_date=start_date, end_date=end_date)
    robot_results = robot_collector.run()
    
    print(f"\nCollected {len(robot_results)} robot articles:")
    for item in robot_results:
        print(f"- [{item.get('date')}] {item.get('raw_title', 'No Title')} ({item.get('source_name', 'Unknown')})")
else:
    print("RobotCollector class not available.")

# %% [markdown]
# ### Anthropic Collector Test

# %%
# Anthropic Collector Test
import sys
import os

# Add backend2 directory to python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))
backend2_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

if backend2_dir not in sys.path:
    sys.path.append(backend2_dir)
if project_root not in sys.path:
    sys.path.append(project_root)

try:
    from agents.collectors.anthropic_collector import AnthropicCollector
    print("Successfully imported AnthropicCollector")
except ImportError as e:
    print(f"Import failed: {e}")
    try:
        from backend2.agents.collectors.anthropic_collector import AnthropicCollector
        print("Successfully imported AnthropicCollector from backend2")
    except ImportError as e2:
        print(f"Import failed again: {e2}")

# Configuration
start_date = "2026-02-01"
end_date = "2026-02-07"

if 'AnthropicCollector' in locals():
    print(f"Running AnthropicCollector from {start_date} to {end_date}...")
    anthropic_collector = AnthropicCollector(start_date=start_date, end_date=end_date)
    anthropic_results = anthropic_collector.run()
    
    print(f"\nCollected {len(anthropic_results)} Anthropic articles:")
    for item in anthropic_results:
        print(f"- [{item.get('date')}] {item.get('raw_title', 'No Title')}")
else:
    print("AnthropicCollector class not available.")

# %% [markdown]
# ### MIT Collector Test

# %%
# MIT Collector Test
import sys
import os

# Add backend2 directory to python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))
backend2_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

if backend2_dir not in sys.path:
    sys.path.append(backend2_dir)
if project_root not in sys.path:
    sys.path.append(project_root)

try:
    from agents.collectors.mit_collector import MITCollector
    print("Successfully imported MITCollector")
except ImportError as e:
    print(f"Import failed: {e}")
    try:
        from backend.agents.collectors.mit_collector import MITCollector
        print("Successfully imported MITCollector from backend2")
    except ImportError as e2:
        print(f"Import failed again: {e2}")

# Configuration
start_date = "2026-02-01"
end_date = "2026-02-07"

if 'MITCollector' in locals():
    print(f"Running MITCollector from {start_date} to {end_date}...")
    mit_collector = MITCollector(start_date=start_date, end_date=end_date)
    mit_results = mit_collector.run()
    
    print(f"\nCollected {len(mit_results)} MIT articles:")
    for item in mit_results:
        print(f"- [{item.get('date')}] {item.get('raw_title', 'No Title')}")
else:
    print("MITCollector class not available.")

# %% [markdown]
# ### NVIDIA Collector Test

# %%
# NVIDIA Collector Test
import sys
import os

# Add backend2 directory to python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))
backend2_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

if backend2_dir not in sys.path:
    sys.path.append(backend2_dir)
if project_root not in sys.path:
    sys.path.append(project_root)

try:
    from agents.collectors.nvidia_collector import NVIDIACollector
    print("Successfully imported NVIDIACollector")
except ImportError as e:
    print(f"Import failed: {e}")
    try:
        from backend.agents.collectors.nvidia_collector import NVIDIACollector
        print("Successfully imported NVIDIACollector from backend2")
    except ImportError as e2:
        print(f"Import failed again: {e2}")

# Configuration
start_date = "2026-02-01"
end_date = "2026-02-07"

if 'NVIDIACollector' in locals():
    print(f"Running NVIDIACollector from {start_date} to {end_date}...")
    nvidia_collector = NVIDIACollector(start_date=start_date, end_date=end_date)
    nvidia_results = nvidia_collector.run()
    
    print(f"\nCollected {len(nvidia_results)} NVIDIA articles:")
    for item in nvidia_results:
        print(f"- [{item.get('date')}] {item.get('raw_title', 'No Title')}")
else:
    print("NVIDIACollector class not available.")

# %% [markdown]
# ### OpenAI Collector Test

# %%
# OpenAI Collector Test
import sys
import os

# Add backend2 directory to python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))
backend2_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

if backend2_dir not in sys.path:
    sys.path.append(backend2_dir)
if project_root not in sys.path:
    sys.path.append(project_root)

try:
    from agents.collectors.openai_collector import OpenAICollector
    print("Successfully imported OpenAICollector")
except ImportError as e:
    print(f"Import failed: {e}")
    try:
        from backend.agents.collectors.openai_collector import OpenAICollector
        print("Successfully imported OpenAICollector from backend2")
    except ImportError as e2:
        print(f"Import failed again: {e2}")

# Configuration
start_date = "2026-01-28"
end_date = "2026-01-28"

if 'OpenAICollector' in locals():
    print(f"Running OpenAICollector from {start_date} to {end_date}...")
    openai_collector = OpenAICollector(start_date=start_date, end_date=end_date)
    openai_results = openai_collector.run()
    
    print(f"\nCollected {len(openai_results)} OpenAI articles:")
    for item in openai_results:
        print(f"- [{item.get('date')}] {item.get('raw_title', 'No Title')}")
else:
    print("OpenAICollector class not available.")

# %% [markdown]
# ### XAICollector (xAI 뉴스)

# %%
# xAI Collector Test
import sys
import os

# Add backend2 directory to python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))
backend2_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

if backend2_dir not in sys.path:
    sys.path.append(backend2_dir)
if project_root not in sys.path:
    sys.path.append(project_root)

try:
    from agents.collectors.xai_collector import XAICollector
    print("Successfully imported XAICollector")
except ImportError as e:
    print(f"Import failed: {e}")
    try:
        from backend.agents.collectors.xai_collector import XAICollector
        print("Successfully imported XAICollector from backend2")
    except ImportError as e2:
        print(f"Import failed again: {e2}")

# Configuration
start_date = "2026-01-28"
end_date = "2026-01-28"

if 'XAICollector' in locals():
    print(f"Running XAICollector from {start_date} to {end_date}...")
    xai_collector = XAICollector(start_date=start_date, end_date=end_date)
    xai_results = xai_collector.run()
    
    print(f"\nCollected {len(xai_results)} xAI articles:")
    for item in xai_results:
        print(f"- [{item.get('date')}] {item.get('raw_title', 'No Title')}")
else:
    print("XAICollector class not available.")

# %% [markdown]
# ### TechCrunch Collector Test

# %%
# TechCrunch Collector Test
import sys
import os

# Add backend2 directory to python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))
backend2_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

if backend2_dir not in sys.path:
    sys.path.append(backend2_dir)
if project_root not in sys.path:
    sys.path.append(project_root)

try:
    from agents.collectors.techcrunch_collector import TechCrunchCollector
    print("Successfully imported TechCrunchCollector")
except ImportError as e:
    print(f"Import failed: {e}")
    try:
        from backend.agents.collectors.techcrunch_collector import TechCrunchCollector
        print("Successfully imported TechCrunchCollector from backend2")
    except ImportError as e2:
        print(f"Import failed again: {e2}")

# Configuration
start_date = "2026-02-08"
end_date = "2026-02-08"

if 'TechCrunchCollector' in locals():
    print(f"Running TechCrunchCollector from {start_date} to {end_date}...")
    techcrunch_collector = TechCrunchCollector(start_date=start_date, end_date=end_date)
    techcrunch_results = techcrunch_collector.run()
    
    print(f"\nCollected {len(techcrunch_results)} TechCrunch articles:")
    for item in techcrunch_results:
        print(f"- [{item.get('date')}] {item.get('raw_title', 'No Title')}")
        print(f"  URL: {item.get('source_url', 'No URL')}")
        print(f"  Content length: {len(item.get('raw_content', ''))} chars")
else:
    print("TechCrunchCollector class not available.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from backend.agents.collectors.techcrunch_collector import TechCrunchCollector
#       2 # 수집기 생성
#       3 collector = TechCrunchCollector(
#       4     start_date="2026-02-08",  # YYYY-MM-DD
#       5     end_date="2026-02-08"
#       6 )
#
# ModuleNotFoundError: No module named 'backend'

# %% [markdown]
# ### Checking Available models

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv
load_dotenv()
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
for model in genai.list_models():
    if 'embedContent' in model.supported_generation_methods:
        print(model.name)
# Out:
# models/gemini-embedding-001
