# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

from backend.agents.collectors.claude_collector import ClaudeCollector
import json

# Test Date requested by user
target_date = "2026-04-10"

collector = ClaudeCollector(target_date, target_date)
results = collector.run()

print(f"\nTotal {len(results)} articles collected for {target_date}\n")
print(json.dumps(results, indent=2, ensure_ascii=False))
# Out:
# [ClaudeCollector] Collecting news from 2026-04-10 to 2026-04-10...
# Starting Claude Scraper (2026-04-10 ~ 2026-04-10)...
#   > [SKIP] out of range: 2026-03-23 (https://claude.com/blog/dispatch-and-computer-use)
#   > [SKIP] out of range: 2025-10-20 (https://claude.com/blog/claude-code-on-the-web)
#   > [SKIP] out of range: 2026-03-30 (https://claude.com/blog/claude-platform-compliance-api)
#   > [SKIP] out of range: 2025-11-12 (https://claude.com/blog/improving-frontend-design-through-skills)
#   > [SKIP] out of range: 2026-03-13 (https://claude.com/blog/1m-context-ga)
#   > [SKIP] out of range: 2026-04-09 (https://claude.com/blog/the-advisor-strategy)
#   > [SKIP] out of range: 2025-10-30 (https://claude.com/blog/building-ai-agents-in-financial-services)
#   > [SKIP] out of range: 2026-03-24 (https://claude.com/blog/auto-mode)
#   > [SKIP] out of range: 2026-04-02 (https://claude.com/blog/harnessing-claudes-intelligence)
# ...
